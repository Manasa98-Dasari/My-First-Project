# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&listingSource=Homepage_Filters&storeCityId=3686")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('h3').get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Today at' ))

# %%
car_dealer

# %%
car_dealer.to_csv('first_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-tata-tiago-cars-hyderabad/")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('h3').get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('second2_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-hyundai-i20-cars-mumbai/")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('h3').get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at '))

# %%
car_dealer

# %%
car_dealer.to_csv('third3_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&storeCityId=2")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('h3').get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Today at'))

# %%
car_dealer

# %%
car_dealer.to_csv('fourth_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&storeCityId=4709")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('fifth_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&storeCityId=777")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('h3').get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('sixth_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&storeCityId=4747")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('seven_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&storeCityId=2423")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at Tathawade,'))

# %%
car_dealer

# %%
car_dealer.to_csv('nine_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&storeCityId=4709")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered/Mileage/Fuel/owner':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Today at'))

# %%
car_dealer

# %%
car_dealer.to_csv('eight_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Arenault%3Bmodel%3Ain%3Akwid&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=134")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('ten_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A500001%2C700000&f=make%3A%3D%3Arenault%3Bmodel%3Ain%3Akwid%3AOR%3Amake%3A%3D%3Ahyundai%3Bmodel%3Ain%3Aelite%20i20&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=3686")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('11_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Ahyundai%3Bmodel%3Ain%3Aelite%20i20%2Cgrand%20i10%3AOR%3Amake%3A%3D%3Atata%3Bmodel%3Ain%3Atiago&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5732")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at hiruverkadu,Navalur,\n'))

# %%
car_dealer

# %%
car_dealer.to_csv('12_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Ahyundai%3Bmodel%3Ain%3Aelite%20i20%3AOR%3Amake%3A%3D%3Arenault%3Bmodel%3Ain%3Akwid%3AOR%3Amake%3A%3D%3Amaruti%3Bmodel%3Ain%3Acelerio&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5732")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('13_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Ahyundai%3Bmodel%3Ain%3Aelite%20i20%3AOR%3Amake%3A%3D%3Amaruti%3Bmodel%3Ain%3Aalto%2Cs%20presso&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5732")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at,Navalur,Thiruverkadu,\n'))

# %%
car_dealer

# %%
car_dealer.to_csv('14_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Ahyundai%3Bmodel%3Ain%3Aelite%20i20%2Cgrand%20i10%3AOR%3Amake%3A%3D%3Amaruti%3Bmodel%3Ain%3Aalto%2Cs%20presso&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=1692")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('15_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Ahyundai%3Bmodel%3Ain%3Agrand%20i10%3AOR%3Amake%3A%3D%3Amaruti%3Bmodel%3Ain%3Aalto%2Cs%20presso&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('16_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Amaruti%3Bmodel%3Ain%3Aalto%2Cs%20presso%2Ccelerio%3AOR%3Amake%3A%3D%3Ahonda%3Bmodel%3Ain%3Aamaze&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('17_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Amaruti%3Bmodel%3Ain%3Aalto%2Cs%20presso%3AOR%3Amake%3A%3D%3Ahyundai%3Bmodel%3Ain%3Aelite%20i20&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer

# %%
car_dealer.to_csv('18_page_car_details.csv',index=False)

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.cars24.com/buy-used-car?f=listingPrice%3Abw%3A300000%2C500000&f=make%3A%3D%3Amaruti%3Bmodel%3Ain%3Aalto%2Cs%20presso%3AOR%3Amake%3A%3D%3Arenault%3Bmodel%3Ain%3Akwid%3AOR%3Amake%3A%3D%3Ahonda%3Bmodel%3Ain%3Aamaze&sort=bestmatch&serveWarrantyCount=true&gaId=258606858.1726297103&listingSource=TabFilter&storeCityId=5")

# %%
web.status_code

# %%
web.content

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
soup

# %%
results=soup.find_all('div',{'class':"_7jb8Q _1Ey60"})

# %%
len(results)

# %%
results[0].get_text()

# %%
results[1].get_text()

# %%
results[1].find('h3',{'class':'_2Out2'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul-'}).get_text()

# %%
results[1].find('div',{'class':'_1Oul- VMjdr'}).get_text()

# %%
results[1].find('ul',{'class':'_3jRcd'}).get_text()

# %%
results[1].find('p',{'class':'_2rxhF'}).get_text()

# %%
name=[]
emi=[]
price=[]
mileage=[]
location=[]
for dell in results:
    try:
        name.append(dell.find('h3').get_text())
    except:
        name.append('n/a')
    try:
        emi.append(dell.find('div',{'class':'_1Oul-'}).get_text())
    except:
        emi.append('n/a')
    try:
        price.append(dell.find('div',{'class':'_1Oul- VMjdr'}).get_text())
    except:
        price.append('n/a')
    try:
        mileage.append(dell.find('ul',{'class':'_3jRcd'}).get_text())
    except:
        mileage.append('n/a')
    try:
        location.append(dell.find('p',{'class':'_2rxhF'}).get_text())
    except:
        location.append('n/a')

# %%
len(name)

# %%
import pandas as pd

# %%
car_dealer=pd.DataFrame({'Name':name,  'EMI':emi, 'Price':price, 'Registered------Mileage-----Fuel-----owner  ':mileage,'Address':location})

# %%
car_dealer

# %%
car_dealer['Address']=car_dealer['Address'].apply(lambda x:x.strip('Free Test Drive Tomorrow at'))

# %%
car_dealer
